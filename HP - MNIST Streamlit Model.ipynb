# %%
pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.31.1-py2.py3-none-any.whl (8.4 MB)
#      ---------------------------------------- 8.4/8.4 MB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata<8,>=1.4 in c:\users\admin\anaconda3\lib\site-packages (from streamlit) (4.11.3)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\admin\anaconda3\lib\site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\admin\anaconda3\lib\site-packages (from streamlit) (2.1.6)
# Collecting blinker<2,>=1.0.0
#   Downloading blinker-1.7.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\admin\anaconda3\lib\site-packages (from streamlit) (4.25.2)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\admin\anaconda3\lib\site-packages (from streamlit) (1.23.5)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\admin\anaconda3\lib\site-packages (from streamlit) (2.2.0)
# Collecting validators<1,>=0.2
#   Downloading validators-0.22.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\admin\anaconda3\lib\site-packages (from streamlit) (4.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\admin\anaconda3\lib\site-packages (from streamlit) (5.3.2)
# Collecting rich<14,>=10.14.0
#   Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#      -------------------------------------- 240.7/240.7 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=7.0 in c:\users\admin\anaconda3\lib\site-packages (from streamlit) (15.0.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\admin\anaconda3\lib\site-packages (from streamlit) (8.0.4)
# Collecting pydeck<1,>=0.8.0b4
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#      ---------------------------------------- 4.8/4.8 MB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging<24,>=16.8 in c:\users\admin\anaconda3\lib\site-packages (from streamlit) (22.0)
# Collecting tzlocal<6,>=1.1
#   Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\admin\anaconda3\lib\site-packages (from streamlit) (6.1)
# Collecting gitpython!=3.1.19,<4,>=3.0.7
#   Downloading GitPython-3.1.42-py3-none-any.whl (195 kB)
#      -------------------------------------- 195.4/195.4 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: altair<6,>=4.0 in c:\users\admin\anaconda3\lib\site-packages (from streamlit) (5.2.0)
# Collecting tenacity<9,>=8.1.0
#   Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\admin\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\admin\anaconda3\lib\site-packages (from streamlit) (9.4.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in c:\users\admin\anaconda3\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\admin\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: jinja2 in c:\users\admin\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: toolz in c:\users\admin\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ---------------------------------------- 62.7/62.7 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in c:\users\admin\anaconda3\lib\site-packages (from importlib-metadata<8,>=1.4->streamlit) (3.11.0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\lib\site-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.16.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Collecting pygments<3.0.0,>=2.13.0
#   Downloading pygments-2.17.2-py3-none-any.whl (1.2 MB)
#      ---------------------------------------- 1.2/1.2 MB 9.4 MB/s eta 0:00:00
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ---------------------------------------- 87.5/87.5 kB 4.8 MB/s eta 0:00:00
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: validators, tzlocal, tenacity, smmap, pygments, mdurl, blinker, pydeck, markdown-it-py, gitdb, rich, gitpython, streamlit
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.0.1
#     Uninstalling tenacity-8.0.1:
#       Successfully uninstalled tenacity-8.0.1
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.11.2
#     Uninstalling Pygments-2.11.2:
#       Successfully uninstalled Pygments-2.11.2
# Successfully installed blinker-1.7.0 gitdb-4.0.11 gitpython-3.1.42 markdown-it-py-3.0.0 mdurl-0.1.2 pydeck-0.8.1b0 pygments-2.17.2 rich-13.7.1 smmap-5.0.1 streamlit-1.31.1 tenacity-8.2.3 tzlocal-5.2 validators-0.22.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.utils import to_categorical
import streamlit as st
from PIL import Image

def load_and_preproess_data():
    (X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
    
    X_train =  X_train.astype('float32') / 255.0
    X_test = X_test.astype('float32') / 255.0
    
    X_train = np.expand_dims(X_train, axis=-1)
    X_test = np.expand_dims(X_test, axis=-1)
    
    y_train = to_categorical(y_train, 10)
    y_test = to_categorical(y_test, 10)
    
    return X_train, y_train, X_test, y_test

def create_model(input_shape):
    model = Sequential([
     Conv2D(32, (3, 3), activation='relu', input_shape=input_shape),
     MaxPooling2D((2, 2)),
     Conv2D(64, (3, 3), activation='relu'),
     MaxPooling2D((2, 2)),
     Flatten(),
     Dense(64, activation='relu'),
     Dense(10, activation='softmax')
    ])
    
    return model

def train_model(model, X_train, y_train, X_test, y_test):
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    early_stop = EarlyStopping(monitor='val_loss', patience=3)
    
    model.fit(X_train, y_train, epochs=20, batch_size=64, validation_data=(X_test,y_test),callbacks=[early_stop])
    
    return model

def evaluate_model(model, X_test, y_test):
    loss, accuracy = model.evaluate(X_test, y_test)
    return loss, accuracy

def save_model(model, filename):
    model.save(filename)

if __name__ == "_main_":
    X_train, y_train, X_test, y_test = load_and_preprocess_data()
    model = create_model(X_train.shape[1:])
    trained_model = train_model(model, X_train, y_train, X_test, y_test)
    loss, accuracy = evaluate_model(trained_model, X_test, y_test)
    save_model(trained_model, "fashion_mnist_cnn_model.h5")
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# WARNING:tensorflow:From C:\Users\admin\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
